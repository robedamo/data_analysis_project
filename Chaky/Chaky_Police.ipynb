# %% [markdown]
# # Police Project (Chaky)
#
# ##  We obtain the data from: https://analisi.transparenciacatalunya.cat/Seguretat/V-ctimes-o-persones-autores-de-delictes-d-odi-i-di/gci6-2ubm

# %%
#!/usr/bin/env python

# make sure to install these packages before running:
# pip install pandas
# pip install sodapy

import pandas as pd
from sodapy import Socrata

# Unauthenticated client only works with public data sets. Note 'None'
# in place of application token, and no username or password:
client = Socrata("analisi.transparenciacatalunya.cat", None)

# Example authenticated client (needed for non-public datasets):
# client = Socrata(analisi.transparenciacatalunya.cat,
#                  MyAppToken,
#                  username="user@example.com",
#                  password="AFakePassword")

# First 2000 results, returned as JSON from API / converted to Python list of
# dictionaries by sodapy.
results = client.get("gci6-2ubm", limit=2000)

# Convert to pandas DataFrame
results_df = pd.DataFrame.from_records(results)
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.

# %%
results_df
# Out:
#        any n_m_mes   nom_mes            regi_policial_rp  \
# 0     2020       1     Gener         RP Terres de l'Ebre
# 1     2020       1     Gener         RP Terres de l'Ebre
# 2     2020       1     Gener      RP  Metropolitana Nord
# 3     2020       1     Gener      RP  Metropolitana Nord
# 4     2020       1     Gener  RP Metropolitana Barcelona
# ...    ...     ...       ...                         ...
# 1964  2021      12  Desembre                  RP Central
# 1965  2021      12  Desembre      RP  Metropolitana Nord
# 1966  2021      12  Desembre      RP  Metropolitana Nord
# 1967  2021      12  Desembre                   RP Girona
# 1968  2021      12  Desembre                   RP Girona
#
#      rea_b_sica_policial_abp  prov_ncia            comarca  \
# 0              ABP Baix Ebre  Tarragona          Baix Ebre
# 1              ABP Baix Ebre  Tarragona          Baix Ebre
# 2                   ABP Rubí  Barcelona  Vallès Occidental
# 3                   ABP Rubí  Barcelona  Vallès Occidental
# 4               ABP Eixample  Barcelona         Barcelonès
# ...                      ...        ...                ...
# 1964               ABP Osona  Barcelona              Osona
# 1965   ABP Mollet del Vallès  Barcelona    Vallès Oriental
# 1966   ABP Mollet del Vallès  Barcelona    Vallès Oriental
# 1967      ABP Selva Interior     Girona              Selva
# 1968      ABP Selva Interior     Girona              Selva
#
#                                 municipi  \
# 0       Resta de municipis ABP Baix Ebre
# 1       Resta de municipis ABP Baix Ebre
# 2                  Sant Cugat del Vallès
# 3                  Sant Cugat del Vallès
# 4                              Barcelona
# ...                                  ...
# 1964          Santa Eulàlia de Riuprimer
# 1965                   Mollet del Vallès
# 1966                   Mollet del Vallès
# 1967             Sant Feliu de Buixalleu
# 1968  Resta municipis ABP Selva Interior
#
#                       tipus_de_lloc_dels_fets tipus_de_fet  \
# 0                          Via pública urbana     Delictes
# 1                          Via pública urbana     Delictes
# 2     Centre de dia/Residència persones grans     Delictes
# 3     Centre de dia/Residència persones grans     Delictes
# 4                           Zona d'oci/lúdica     Delictes
# ...                                       ...          ...
# 1964       Dependències - Administració local      Delicte
# 1965                       Via pública urbana      Delicte
# 1966                       Via pública urbana      Delicte
# 1967                                  Càmping      Delicte
# 1968                                  Càmping      Delicte
#
#                               tipus_de_fet_codi_penal_o  \
# 0                                              Amenaces
# 1                                              Amenaces
# 2     Contra exercici drets fonamentals i llibertats...
# 3     Contra exercici drets fonamentals i llibertats...
# 4                Robatori amb violència i/o intimidació
# ...                                                 ...
# 1964                                               Furt
# 1965                                           Amenaces
# 1966                                           Amenaces
# 1967                                            Lesions
# 1968                                            Lesions
#
#                      mbit_procediment_fet rol_v_ctima_o_autoria  sexe  \
# 0       Ètnic, origen nacional i/o racial              Víctimes  Home
# 1       Ètnic, origen nacional i/o racial              Víctimes  Home
# 2       Ètnic, origen nacional i/o racial              Víctimes  Dona
# 3       Ètnic, origen nacional i/o racial      Persones autores  Home
# 4                             LGTBI-fòbia              Víctimes  Home
# ...                                   ...                   ...   ...
# 1964                  Orientació política               Víctima  Home
# 1965  Ètnia/origen nacional/origen racial               Víctima  Dona
# 1966  Ètnia/origen nacional/origen racial        Persona autora  Home
# 1967                          LGTBI-fòbia               Víctima  Home
# 1968                          LGTBI-fòbia        Persona autora  Home
#
#      edat_inici_fets nombre
# 0                 21      1
# 1                 19      1
# 2                 44      1
# 3                 79      1
# 4                 28      1
# ...              ...    ...
# 1964              42      1
# 1965              19      1
# 1966              30      1
# 1967              46      1
# 1968              27      1
#
# [1969 rows x 16 columns]

# %%
results_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1969 entries, 0 to 1968
# Data columns (total 16 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   any                        1969 non-null   object
#  1   n_m_mes                    1969 non-null   object
#  2   nom_mes                    1969 non-null   object
#  3   regi_policial_rp           1969 non-null   object
#  4   rea_b_sica_policial_abp    1969 non-null   object
#  5   prov_ncia                  1969 non-null   object
#  6   comarca                    1969 non-null   object
#  7   municipi                   1969 non-null   object
#  8   tipus_de_lloc_dels_fets    1969 non-null   object
#  9   tipus_de_fet               1969 non-null   object
#  10  tipus_de_fet_codi_penal_o  1969 non-null   object
#  11  mbit_procediment_fet       1969 non-null   object
#  12  rol_v_ctima_o_autoria      1969 non-null   object
#  13  sexe                       1969 non-null   object
#  14  edat_inici_fets            1969 non-null   object
#  15  nombre                     1968 non-null   object
# dtypes: object(16)
# memory usage: 246.2+ KB

# %%
results_df_T = results_df.transpose()
results_df_T
# Out:
#                                                         0     \
# any                                                     2020
# n_m_mes                                                    1
# nom_mes                                                Gener
# regi_policial_rp                         RP Terres de l'Ebre
# rea_b_sica_policial_abp                        ABP Baix Ebre
# prov_ncia                                          Tarragona
# comarca                                            Baix Ebre
# municipi                    Resta de municipis ABP Baix Ebre
# tipus_de_lloc_dels_fets                   Via pública urbana
# tipus_de_fet                                        Delictes
# tipus_de_fet_codi_penal_o                           Amenaces
# mbit_procediment_fet       Ètnic, origen nacional i/o racial
# rol_v_ctima_o_autoria                               Víctimes
# sexe                                                    Home
# edat_inici_fets                                           21
# nombre                                                     1
#
#                                                         1     \
# any                                                     2020
# n_m_mes                                                    1
# nom_mes                                                Gener
# regi_policial_rp                         RP Terres de l'Ebre
# rea_b_sica_policial_abp                        ABP Baix Ebre
# prov_ncia                                          Tarragona
# comarca                                            Baix Ebre
# municipi                    Resta de municipis ABP Baix Ebre
# tipus_de_lloc_dels_fets                   Via pública urbana
# tipus_de_fet                                        Delictes
# tipus_de_fet_codi_penal_o                           Amenaces
# mbit_procediment_fet       Ètnic, origen nacional i/o racial
# rol_v_ctima_o_autoria                               Víctimes
# sexe                                                    Home
# edat_inici_fets                                           19
# nombre                                                     1
#
#                                                                         2     \
# any                                                                     2020
# n_m_mes                                                                    1
# nom_mes                                                                Gener
# regi_policial_rp                                      RP  Metropolitana Nord
# rea_b_sica_policial_abp                                             ABP Rubí
# prov_ncia                                                          Barcelona
# comarca                                                    Vallès Occidental
# municipi                                               Sant Cugat del Vallès
# tipus_de_lloc_dels_fets              Centre de dia/Residència persones grans
# tipus_de_fet                                                        Delictes
# tipus_de_fet_codi_penal_o  Contra exercici drets fonamentals i llibertats...
# mbit_procediment_fet                       Ètnic, origen nacional i/o racial
# rol_v_ctima_o_autoria                                               Víctimes
# sexe                                                                    Dona
# edat_inici_fets                                                           44
# nombre                                                                     1
#
#                                                                         3     \
# any                                                                     2020
# n_m_mes                                                                    1
# nom_mes                                                                Gener
# regi_policial_rp                                      RP  Metropolitana Nord
# rea_b_sica_policial_abp                                             ABP Rubí
# prov_ncia                                                          Barcelona
# comarca                                                    Vallès Occidental
# municipi                                               Sant Cugat del Vallès
# tipus_de_lloc_dels_fets              Centre de dia/Residència persones grans
# tipus_de_fet                                                        Delictes
# tipus_de_fet_codi_penal_o  Contra exercici drets fonamentals i llibertats...
# mbit_procediment_fet                       Ètnic, origen nacional i/o racial
# rol_v_ctima_o_autoria                                       Persones autores
# sexe                                                                    Home
# edat_inici_fets                                                           79
# nombre                                                                     1
#
#                                                              4     \
# any                                                          2020
# n_m_mes                                                         1
# nom_mes                                                     Gener
# regi_policial_rp                       RP Metropolitana Barcelona
# rea_b_sica_policial_abp                              ABP Eixample
# prov_ncia                                               Barcelona
# comarca                                                Barcelonès
# municipi                                                Barcelona
# tipus_de_lloc_dels_fets                         Zona d'oci/lúdica
# tipus_de_fet                                             Delictes
# tipus_de_fet_codi_penal_o  Robatori amb violència i/o intimidació
# mbit_procediment_fet                                  LGTBI-fòbia
# rol_v_ctima_o_autoria                                    Víctimes
# sexe                                                         Home
# edat_inici_fets                                                28
# nombre                                                          1
#
#                                                                      5     \
# any                                                                  2020
# n_m_mes                                                                 1
# nom_mes                                                             Gener
# regi_policial_rp                                   RP  Metropolitana Nord
# rea_b_sica_policial_abp                                    ABP Cerdanyola
# prov_ncia                                                       Barcelona
# comarca                                                 Vallès Occidental
# municipi                                            Cerdanyola del Vallès
# tipus_de_lloc_dels_fets    Habitatge - Primera residència - Casa adossada
# tipus_de_fet                                                     Delictes
# tipus_de_fet_codi_penal_o                                    Danys (lleu)
# mbit_procediment_fet                                  Orientació política
# rol_v_ctima_o_autoria                                            Víctimes
# sexe                                                                 Dona
# edat_inici_fets                                                        59
# nombre                                                                  1
#
#                                            6     \
# any                                        2020
# n_m_mes                                       1
# nom_mes                                   Gener
# regi_policial_rp           RP Camp de Tarragona
# rea_b_sica_policial_abp          ABP Tarragonès
# prov_ncia                             Tarragona
# comarca                              Tarragonès
# municipi                              Tarragona
# tipus_de_lloc_dels_fets          Partit polític
# tipus_de_fet                           Delictes
# tipus_de_fet_codi_penal_o      Coaccions (lleu)
# mbit_procediment_fet        Orientació política
# rol_v_ctima_o_autoria                  Víctimes
# sexe                                       Home
# edat_inici_fets                              37
# nombre                                        1
#
#                                                                         7     \
# any                                                                     2020
# n_m_mes                                                                    1
# nom_mes                                                                Gener
# regi_policial_rp                                  RP Metropolitana Barcelona
# rea_b_sica_policial_abp                                      ABP Sant Andreu
# prov_ncia                                                          Barcelona
# comarca                                                           Barcelonès
# municipi                                                           Barcelona
# tipus_de_lloc_dels_fets                                   Via pública urbana
# tipus_de_fet                                                        Delictes
# tipus_de_fet_codi_penal_o  Contra exercici drets fonamentals i llibertats...
# mbit_procediment_fet                       Ètnic, origen nacional i/o racial
# rol_v_ctima_o_autoria                                               Víctimes
# sexe                                                                    Home
# edat_inici_fets                                                           19
# nombre                                                                     1
#
#                                                                         8     \
# any                                                                     2020
# n_m_mes                                                                    1
# nom_mes                                                                Gener
# regi_policial_rp                                  RP Metropolitana Barcelona
# rea_b_sica_policial_abp                                      ABP Sant Andreu
# prov_ncia                                                          Barcelona
# comarca                                                           Barcelonès
# municipi                                                           Barcelona
# tipus_de_lloc_dels_fets                                   Via pública urbana
# tipus_de_fet                                                        Delictes
# tipus_de_fet_codi_penal_o  Contra exercici drets fonamentals i llibertats...
# mbit_procediment_fet                       Ètnic, origen nacional i/o racial
# rol_v_ctima_o_autoria                                               Víctimes
# sexe                                                                    Home
# edat_inici_fets                                                           18
# nombre                                                                     1
#
#                                                                       9     \
# any                                                                   2020
# n_m_mes                                                                  1
# nom_mes                                                              Gener
# regi_policial_rp                                                 RP Ponent
# rea_b_sica_policial_abp              ABP Segrià - Garrigues - Pla d'Urgell
# prov_ncia                                                           Lleida
# comarca                                                             Segrià
# municipi                                                            Lleida
# tipus_de_lloc_dels_fets    Habitatge - Primera residència - Pis/apartament
# tipus_de_fet                                                      Delictes
# tipus_de_fet_codi_penal_o                                  Amenaces (lleu)
# mbit_procediment_fet                     Ètnic, origen nacional i/o racial
# rol_v_ctima_o_autoria                                             Víctimes
# sexe                                                                  Home
# edat_inici_fets                                                         19
# nombre                                                                   1
#
#                            ...                                   1959  \
# any                        ...                                   2021
# n_m_mes                    ...                                     12
# nom_mes                    ...                               Desembre
# regi_policial_rp           ...                             RP Central
# rea_b_sica_policial_abp    ...                              ABP Anoia
# prov_ncia                  ...                              Barcelona
# comarca                    ...                                  Anoia
# municipi                   ...               els Hostalets de Pierola
# tipus_de_lloc_dels_fets    ...  Habitatge - Escala/portal finca/replà
# tipus_de_fet               ...                                Delicte
# tipus_de_fet_codi_penal_o  ...                               Amenaces
# mbit_procediment_fet       ...                            LGTBI-fòbia
# rol_v_ctima_o_autoria      ...                                Víctima
# sexe                       ...                                   Home
# edat_inici_fets            ...                                     26
# nombre                     ...                                      1
#
#                                                             1960  \
# any                                                         2021
# n_m_mes                                                       12
# nom_mes                                                 Desembre
# regi_policial_rp                                      RP Central
# rea_b_sica_policial_abp                                ABP Anoia
# prov_ncia                                              Barcelona
# comarca                                                    Anoia
# municipi                                els Hostalets de Pierola
# tipus_de_lloc_dels_fets    Habitatge - Escala/portal finca/replà
# tipus_de_fet                                             Delicte
# tipus_de_fet_codi_penal_o                               Amenaces
# mbit_procediment_fet                                 LGTBI-fòbia
# rol_v_ctima_o_autoria                                    Víctima
# sexe                                                        Home
# edat_inici_fets                                               26
# nombre                                                         1
#
#                                                             1961  \
# any                                                         2021
# n_m_mes                                                       12
# nom_mes                                                 Desembre
# regi_policial_rp                                      RP Central
# rea_b_sica_policial_abp                                ABP Anoia
# prov_ncia                                              Barcelona
# comarca                                                    Anoia
# municipi                               Resta municipis ABP Anoia
# tipus_de_lloc_dels_fets    Habitatge - Escala/portal finca/replà
# tipus_de_fet                                             Delicte
# tipus_de_fet_codi_penal_o                               Amenaces
# mbit_procediment_fet                                 LGTBI-fòbia
# rol_v_ctima_o_autoria                             Persona autora
# sexe                                                        Home
# edat_inici_fets                                               27
# nombre                                                         1
#
#                                                             1962  \
# any                                                         2021
# n_m_mes                                                       12
# nom_mes                                                 Desembre
# regi_policial_rp                                      RP Central
# rea_b_sica_policial_abp                                ABP Anoia
# prov_ncia                                              Barcelona
# comarca                                                    Anoia
# municipi                               Resta municipis ABP Anoia
# tipus_de_lloc_dels_fets    Habitatge - Escala/portal finca/replà
# tipus_de_fet                                             Delicte
# tipus_de_fet_codi_penal_o                               Amenaces
# mbit_procediment_fet                                 LGTBI-fòbia
# rol_v_ctima_o_autoria                             Persona autora
# sexe                                                        Home
# edat_inici_fets                                               28
# nombre                                                         1
#
#                                                             1963  \
# any                                                         2021
# n_m_mes                                                       12
# nom_mes                                                 Desembre
# regi_policial_rp                                      RP Central
# rea_b_sica_policial_abp                                ABP Anoia
# prov_ncia                                              Barcelona
# comarca                                                    Anoia
# municipi                                els Hostalets de Pierola
# tipus_de_lloc_dels_fets    Habitatge - Escala/portal finca/replà
# tipus_de_fet                                             Delicte
# tipus_de_fet_codi_penal_o                               Amenaces
# mbit_procediment_fet                                 LGTBI-fòbia
# rol_v_ctima_o_autoria                                    Víctima
# sexe                                                        Home
# edat_inici_fets                                               26
# nombre                                                         1
#
#                                                          1964  \
# any                                                      2021
# n_m_mes                                                    12
# nom_mes                                              Desembre
# regi_policial_rp                                   RP Central
# rea_b_sica_policial_abp                             ABP Osona
# prov_ncia                                           Barcelona
# comarca                                                 Osona
# municipi                           Santa Eulàlia de Riuprimer
# tipus_de_lloc_dels_fets    Dependències - Administració local
# tipus_de_fet                                          Delicte
# tipus_de_fet_codi_penal_o                                Furt
# mbit_procediment_fet                      Orientació política
# rol_v_ctima_o_autoria                                 Víctima
# sexe                                                     Home
# edat_inici_fets                                            42
# nombre                                                      1
#
#                                                           1965  \
# any                                                       2021
# n_m_mes                                                     12
# nom_mes                                               Desembre
# regi_policial_rp                        RP  Metropolitana Nord
# rea_b_sica_policial_abp                  ABP Mollet del Vallès
# prov_ncia                                            Barcelona
# comarca                                        Vallès Oriental
# municipi                                     Mollet del Vallès
# tipus_de_lloc_dels_fets                     Via pública urbana
# tipus_de_fet                                           Delicte
# tipus_de_fet_codi_penal_o                             Amenaces
# mbit_procediment_fet       Ètnia/origen nacional/origen racial
# rol_v_ctima_o_autoria                                  Víctima
# sexe                                                      Dona
# edat_inici_fets                                             19
# nombre                                                       1
#
#                                                           1966  \
# any                                                       2021
# n_m_mes                                                     12
# nom_mes                                               Desembre
# regi_policial_rp                        RP  Metropolitana Nord
# rea_b_sica_policial_abp                  ABP Mollet del Vallès
# prov_ncia                                            Barcelona
# comarca                                        Vallès Oriental
# municipi                                     Mollet del Vallès
# tipus_de_lloc_dels_fets                     Via pública urbana
# tipus_de_fet                                           Delicte
# tipus_de_fet_codi_penal_o                             Amenaces
# mbit_procediment_fet       Ètnia/origen nacional/origen racial
# rol_v_ctima_o_autoria                           Persona autora
# sexe                                                      Home
# edat_inici_fets                                             30
# nombre                                                       1
#
#                                               1967  \
# any                                           2021
# n_m_mes                                         12
# nom_mes                                   Desembre
# regi_policial_rp                         RP Girona
# rea_b_sica_policial_abp         ABP Selva Interior
# prov_ncia                                   Girona
# comarca                                      Selva
# municipi                   Sant Feliu de Buixalleu
# tipus_de_lloc_dels_fets                    Càmping
# tipus_de_fet                               Delicte
# tipus_de_fet_codi_penal_o                  Lesions
# mbit_procediment_fet                   LGTBI-fòbia
# rol_v_ctima_o_autoria                      Víctima
# sexe                                          Home
# edat_inici_fets                                 46
# nombre                                           1
#
#                                                          1968
# any                                                      2021
# n_m_mes                                                    12
# nom_mes                                              Desembre
# regi_policial_rp                                    RP Girona
# rea_b_sica_policial_abp                    ABP Selva Interior
# prov_ncia                                              Girona
# comarca                                                 Selva
# municipi                   Resta municipis ABP Selva Interior
# tipus_de_lloc_dels_fets                               Càmping
# tipus_de_fet                                          Delicte
# tipus_de_fet_codi_penal_o                             Lesions
# mbit_procediment_fet                              LGTBI-fòbia
# rol_v_ctima_o_autoria                          Persona autora
# sexe                                                     Home
# edat_inici_fets                                            27
# nombre                                                      1
#
# [16 rows x 1969 columns]

# %% [markdown]
# ### LLISTA DE LES CATEGORIES

# %%
#OBTENGO LISTA DE TODAS LAS CATEGORÍAS

results_df_T = results_df_T.reset_index()
results_df_T

results_df_categories = results_df_T.loc[:,'index']

llista_categories = []


for i in results_df_categories:
    llista_categories.append(i)
    
    
print(len(llista_categories))
print(llista_categories)
# Out:
# 16
# ['any', 'n_m_mes', 'nom_mes', 'regi_policial_rp', 'rea_b_sica_policial_abp', 'prov_ncia', 'comarca', 'municipi', 'tipus_de_lloc_dels_fets', 'tipus_de_fet', 'tipus_de_fet_codi_penal_o', 'mbit_procediment_fet', 'rol_v_ctima_o_autoria', 'sexe', 'edat_inici_fets', 'nombre']

# %%
results_df_T
# Out:
#                         index                                  0  \
# 0                         any                               2020
# 1                     n_m_mes                                  1
# 2                     nom_mes                              Gener
# 3            regi_policial_rp                RP Terres de l'Ebre
# 4     rea_b_sica_policial_abp                      ABP Baix Ebre
# 5                   prov_ncia                          Tarragona
# 6                     comarca                          Baix Ebre
# 7                    municipi   Resta de municipis ABP Baix Ebre
# 8     tipus_de_lloc_dels_fets                 Via pública urbana
# 9                tipus_de_fet                           Delictes
# 10  tipus_de_fet_codi_penal_o                           Amenaces
# 11       mbit_procediment_fet  Ètnic, origen nacional i/o racial
# 12      rol_v_ctima_o_autoria                           Víctimes
# 13                       sexe                               Home
# 14            edat_inici_fets                                 21
# 15                     nombre                                  1
#
#                                     1  \
# 0                                2020
# 1                                   1
# 2                               Gener
# 3                 RP Terres de l'Ebre
# 4                       ABP Baix Ebre
# 5                           Tarragona
# 6                           Baix Ebre
# 7    Resta de municipis ABP Baix Ebre
# 8                  Via pública urbana
# 9                            Delictes
# 10                           Amenaces
# 11  Ètnic, origen nacional i/o racial
# 12                           Víctimes
# 13                               Home
# 14                                 19
# 15                                  1
#
#                                                     2  \
# 0                                                2020
# 1                                                   1
# 2                                               Gener
# 3                              RP  Metropolitana Nord
# 4                                            ABP Rubí
# 5                                           Barcelona
# 6                                   Vallès Occidental
# 7                               Sant Cugat del Vallès
# 8             Centre de dia/Residència persones grans
# 9                                            Delictes
# 10  Contra exercici drets fonamentals i llibertats...
# 11                  Ètnic, origen nacional i/o racial
# 12                                           Víctimes
# 13                                               Dona
# 14                                                 44
# 15                                                  1
#
#                                                     3  \
# 0                                                2020
# 1                                                   1
# 2                                               Gener
# 3                              RP  Metropolitana Nord
# 4                                            ABP Rubí
# 5                                           Barcelona
# 6                                   Vallès Occidental
# 7                               Sant Cugat del Vallès
# 8             Centre de dia/Residència persones grans
# 9                                            Delictes
# 10  Contra exercici drets fonamentals i llibertats...
# 11                  Ètnic, origen nacional i/o racial
# 12                                   Persones autores
# 13                                               Home
# 14                                                 79
# 15                                                  1
#
#                                          4  \
# 0                                     2020
# 1                                        1
# 2                                    Gener
# 3               RP Metropolitana Barcelona
# 4                             ABP Eixample
# 5                                Barcelona
# 6                               Barcelonès
# 7                                Barcelona
# 8                        Zona d'oci/lúdica
# 9                                 Delictes
# 10  Robatori amb violència i/o intimidació
# 11                             LGTBI-fòbia
# 12                                Víctimes
# 13                                    Home
# 14                                      28
# 15                                       1
#
#                                                  5                     6  \
# 0                                             2020                  2020
# 1                                                1                     1
# 2                                            Gener                 Gener
# 3                           RP  Metropolitana Nord  RP Camp de Tarragona
# 4                                   ABP Cerdanyola        ABP Tarragonès
# 5                                        Barcelona             Tarragona
# 6                                Vallès Occidental            Tarragonès
# 7                            Cerdanyola del Vallès             Tarragona
# 8   Habitatge - Primera residència - Casa adossada        Partit polític
# 9                                         Delictes              Delictes
# 10                                    Danys (lleu)      Coaccions (lleu)
# 11                             Orientació política   Orientació política
# 12                                        Víctimes              Víctimes
# 13                                            Dona                  Home
# 14                                              59                    37
# 15                                               1                     1
#
#                                                     7  \
# 0                                                2020
# 1                                                   1
# 2                                               Gener
# 3                          RP Metropolitana Barcelona
# 4                                     ABP Sant Andreu
# 5                                           Barcelona
# 6                                          Barcelonès
# 7                                           Barcelona
# 8                                  Via pública urbana
# 9                                            Delictes
# 10  Contra exercici drets fonamentals i llibertats...
# 11                  Ètnic, origen nacional i/o racial
# 12                                           Víctimes
# 13                                               Home
# 14                                                 19
# 15                                                  1
#
#                                                     8  ...  \
# 0                                                2020  ...
# 1                                                   1  ...
# 2                                               Gener  ...
# 3                          RP Metropolitana Barcelona  ...
# 4                                     ABP Sant Andreu  ...
# 5                                           Barcelona  ...
# 6                                          Barcelonès  ...
# 7                                           Barcelona  ...
# 8                                  Via pública urbana  ...
# 9                                            Delictes  ...
# 10  Contra exercici drets fonamentals i llibertats...  ...
# 11                  Ètnic, origen nacional i/o racial  ...
# 12                                           Víctimes  ...
# 13                                               Home  ...
# 14                                                 18  ...
# 15                                                  1  ...
#
#                                      1959  \
# 0                                    2021
# 1                                      12
# 2                                Desembre
# 3                              RP Central
# 4                               ABP Anoia
# 5                               Barcelona
# 6                                   Anoia
# 7                els Hostalets de Pierola
# 8   Habitatge - Escala/portal finca/replà
# 9                                 Delicte
# 10                               Amenaces
# 11                            LGTBI-fòbia
# 12                                Víctima
# 13                                   Home
# 14                                     26
# 15                                      1
#
#                                      1960  \
# 0                                    2021
# 1                                      12
# 2                                Desembre
# 3                              RP Central
# 4                               ABP Anoia
# 5                               Barcelona
# 6                                   Anoia
# 7                els Hostalets de Pierola
# 8   Habitatge - Escala/portal finca/replà
# 9                                 Delicte
# 10                               Amenaces
# 11                            LGTBI-fòbia
# 12                                Víctima
# 13                                   Home
# 14                                     26
# 15                                      1
#
#                                      1961  \
# 0                                    2021
# 1                                      12
# 2                                Desembre
# 3                              RP Central
# 4                               ABP Anoia
# 5                               Barcelona
# 6                                   Anoia
# 7               Resta municipis ABP Anoia
# 8   Habitatge - Escala/portal finca/replà
# 9                                 Delicte
# 10                               Amenaces
# 11                            LGTBI-fòbia
# 12                         Persona autora
# 13                                   Home
# 14                                     27
# 15                                      1
#
#                                      1962  \
# 0                                    2021
# 1                                      12
# 2                                Desembre
# 3                              RP Central
# 4                               ABP Anoia
# 5                               Barcelona
# 6                                   Anoia
# 7               Resta municipis ABP Anoia
# 8   Habitatge - Escala/portal finca/replà
# 9                                 Delicte
# 10                               Amenaces
# 11                            LGTBI-fòbia
# 12                         Persona autora
# 13                                   Home
# 14                                     28
# 15                                      1
#
#                                      1963                                1964  \
# 0                                    2021                                2021
# 1                                      12                                  12
# 2                                Desembre                            Desembre
# 3                              RP Central                          RP Central
# 4                               ABP Anoia                           ABP Osona
# 5                               Barcelona                           Barcelona
# 6                                   Anoia                               Osona
# 7                els Hostalets de Pierola          Santa Eulàlia de Riuprimer
# 8   Habitatge - Escala/portal finca/replà  Dependències - Administració local
# 9                                 Delicte                             Delicte
# 10                               Amenaces                                Furt
# 11                            LGTBI-fòbia                 Orientació política
# 12                                Víctima                             Víctima
# 13                                   Home                                Home
# 14                                     26                                  42
# 15                                      1                                   1
#
#                                    1965                                 1966  \
# 0                                  2021                                 2021
# 1                                    12                                   12
# 2                              Desembre                             Desembre
# 3                RP  Metropolitana Nord               RP  Metropolitana Nord
# 4                 ABP Mollet del Vallès                ABP Mollet del Vallès
# 5                             Barcelona                            Barcelona
# 6                       Vallès Oriental                      Vallès Oriental
# 7                     Mollet del Vallès                    Mollet del Vallès
# 8                    Via pública urbana                   Via pública urbana
# 9                               Delicte                              Delicte
# 10                             Amenaces                             Amenaces
# 11  Ètnia/origen nacional/origen racial  Ètnia/origen nacional/origen racial
# 12                              Víctima                       Persona autora
# 13                                 Dona                                 Home
# 14                                   19                                   30
# 15                                    1                                    1
#
#                        1967                                1968
# 0                      2021                                2021
# 1                        12                                  12
# 2                  Desembre                            Desembre
# 3                 RP Girona                           RP Girona
# 4        ABP Selva Interior                  ABP Selva Interior
# 5                    Girona                              Girona
# 6                     Selva                               Selva
# 7   Sant Feliu de Buixalleu  Resta municipis ABP Selva Interior
# 8                   Càmping                             Càmping
# 9                   Delicte                             Delicte
# 10                  Lesions                             Lesions
# 11              LGTBI-fòbia                         LGTBI-fòbia
# 12                  Víctima                      Persona autora
# 13                     Home                                Home
# 14                       46                                  27
# 15                        1                                   1
#
# [16 rows x 1970 columns]

# %%
results_df.loc[:,'any'].count()
# Out:
# 1969

# %% [markdown]
# ### CONSIGO VALORES NUMÉRICOS DE MIS CATEGORÍAS Y LO ORDENO EN DICCIONARIOS

# %%
boludo = results_df['any'].value_counts()
values_any = []
for i in boludo:
    values_any.append(i)    
#values_any

#boludo.index
respostes_any = []
for i in boludo.index:
    respostes_any.append(i)
    
dic_any = {}
k = 0
while k < len(values_any):
    dic_any[respostes_any[k]] = values_any[k]
    k += 1
dic_any
# Out:
# {'2021': 1027, '2020': 942}

# %%
boludo
# Out:
# 2021    1027
# 2020     942
# Name: any, dtype: int64

# %%
for i in llista_categories:
    boludo = results_df[i].value_counts()
    print(boludo)
    
#boludo, boludo.index
# Out:
# 2021    1027
# 2020     942
# Name: any, dtype: int64
# 6     248
# 2     235
# 7     198
# 8     192
# 5     189
# 10    175
# 9     167
# 11    140
# 3     127
# 12    111
# 4      97
# 1      90
# Name: n_m_mes, dtype: int64
# Juny        248
# Febrer      235
# Juliol      198
# Agost       192
# Maig        189
# Octubre     175
# Setembre    167
# Novembre    140
# Març        127
# Desembre    111
# Abril        97
# Gener        90
# Name: nom_mes, dtype: int64
# RP Metropolitana Barcelona    542
# RP  Metropolitana Nord        422
# RP Metropolitana Sud          250
# RP Girona                     219
# RP Central                    215
# RP Camp de Tarragona          169
# RP Ponent                     124
# RP Terres de l'Ebre            22
# RP Pirineu Occidental           6
# Name: regi_policial_rp, dtype: int64
# ABP Ciutat Vella                         125
# ABP Eixample                             103
# ABP Segrià - Garrigues - Pla d'Urgell     97
# ABP Sant Martí                            97
# ABP Badalona                              84
#                                         ...
# ABP el Prat de Llobregat                   2
# ABP Ripollès                               2
# ABP Noguera                                2
# Unitat d'informació RPMB                   1
# CD Caldes de Montbui                       1
# Name: rea_b_sica_policial_abp, Length: 62, dtype: int64
# Barcelona    1411
# Girona        223
# Tarragona     190
# Lleida        145
# Name: prov_ncia, dtype: int64
# Barcelonès           682
# Vallès Occidental    168
# Baix Llobregat       133
# Vallès Oriental       86
# Segrià                84
# Selva                 79
# Garraf                75
# Gironès               72
# Anoia                 67
# Maresme               65
# Baix Camp             62
# Bages                 56
# Osona                 53
# Baix Penedès          52
# Tarragonès            47
# Alt Empordà           24
# Baix Empordà          22
# Urgell                22
# Solsonès              18
# Baix Ebre             13
# Garrotxa              11
# Moianès               10
# Montsià                9
# Pla de l'Estany        9
# Pla d'Urgell           8
# Berguedà               6
# Alt Penedès            6
# Garrigues              5
# Vic                    4
# Cerdanya               3
# Segarra                3
# Alt Camp               3
# Conca de Barberà       3
# Val d'Aran             3
# Noguera                2
# Ripollès               2
# Priorat                1
# Bagès                  1
# Name: comarca, dtype: int64
# Barcelona                  541
# Lleida                      76
# Badalona                    74
# Girona                      49
# Sabadell                    47
#                           ...
# Vila-seca                    1
# Anglesola                    1
# Martorell                    1
# Olèrdola                     1
# Sant Feliu de Buixalleu      1
# Name: municipi, Length: 214, dtype: int64
# Via pública urbana                                 869
# Habitatge - Primera residència - Pis/apartament    283
# Habitatge - Primera residència - Casa adossada      61
# Habitatge - Escala/portal finca/replà               60
# Institut d'Educació                                 55
#                                                   ...
# Oficines/Despatxos professionals                     1
# Edifici/Infraestructura en desús                     1
# Dependències - Policia local                         1
# Establiments - Discoteca de joventut                 1
# Establiment - Benzinera - Centre comercial           1
# Name: tipus_de_lloc_dels_fets, Length: 96, dtype: int64
# Delicte                     958
# Delictes                    931
# Altres                       45
# Infracció administrativa     24
# Faltes Administratives       11
# Name: tipus_de_fet, dtype: int64
# Contra exercici drets fonamentals i llibertats públiques                            561
# Lesions                                                                             241
# Amenaces                                                                            223
# Amenaces (lleu)                                                                     164
# Lesions (lleu)                                                                      138
# Tracte degradant / vexatori                                                         109
# Danys                                                                               108
# Robatori amb violència i/o intimidació                                               69
# Diligències informatives                                                             45
# Injúria                                                                              32
# Furt                                                                                 29
# Assetjament                                                                          24
# Danys (lleu)                                                                         23
# Coaccions                                                                            20
# Coaccions (lleu)                                                                     15
# Furt (lleu)                                                                          15
# Danys / deslluïments de béns mobles / immobles                                       15
# Trencament de condemna                                                               12
# Violència física o psíquica habitual en l'àmbit familiar                             10
# Abusos sexuals                                                                        9
# Descobriment i revelació de secrets                                                   9
# Falta de maltractament d'obra sense lesió                                             9
# Injúria (lleu)                                                                        8
# Contra la llibertat de consciència, religió i respecte als difunts                    7
# Contra la llibertat de consciència i sentiments religiosos                            5
# Desordres públics                                                                     5
# Robatori amb força interior vehicle                                                   4
# Actes d'exhibició obscena/atemptat llibertat sexual                                   4
# Entrada a domicili aliè                                                               4
# Lesions (pèrdua membre/òrgan principal)                                               4
# Homicidi dolós (inclou temptativa i consumat)                                         4
# Maltractaments en l'àmbit de la llar                                                  3
# Robatori amb força                                                                    3
# Contra les institucions de l'Estat i divisió de poders                                3
# Assassinat                                                                            3
# Altres delictes contra l'ordre públic                                                 3
# Reunió, manifestació no comunicada                                                    2
# Assetjament/comportament agressiu vers col·lectiu                                     2
# Agressions sexuals                                                                    2
# Contra la comunitat internacional                                                     2
# Atemptat a autoritat, agents de l' autoritat i resistència i desobediència            2
# Trencament de condemna (resolució judicial)                                           2
# Emetre públicament expressions vexatòries                                             2
# Assetjament sexual                                                                    2
# Actes d'exhibició obscena/atempten contra la llibertat sexual                         2
# Incendi                                                                               2
# Abusos sexuals (víctima menor de 16 anys)                                             2
# Reunió, manifestació no comunicada/prohibida instal·lació bàsica                      2
# Infraccions ordenança convivència ciutadana                                           1
# Actes comportin aïllament, rebuig o menyspreu                                         1
# Diversos sense especificar                                                            1
# Falta de respecte i consideració a persones membres Forces i Cossos de Seguretat      1
# Estafes                                                                               1
# Name: tipus_de_fet_codi_penal_o, dtype: int64
# LGTBI-fòbia                            870
# Ètnic, origen nacional i/o racial      350
# Ètnia/origen nacional/origen racial    330
# Orientació política                    287
# Sexisme                                 43
# Religiós                                38
# Antisemita                              16
# Discapacitat física/sensorial           15
# Aporofòbia                               8
# Discapactiat psíquica/mental             6
# Discapacitat psíquica/mental             6
# Name: mbit_procediment_fet, dtype: int64
# Víctima             580
# Víctimes            557
# Persona autora      446
# Persones autores    385
# víctima               1
# Name: rol_v_ctima_o_autoria, dtype: int64
# Home    1366
# Dona     603
# Name: sexe, dtype: int64
# 14    64
# 15    59
# 19    57
# 47    52
# 42    51
#       ..
# 9      1
# 5      1
# 78     1
# 2      1
# 90     1
# Name: edat_inici_fets, Length: 78, dtype: int64
# 1    1968
# Name: nombre, dtype: int64

# %% [markdown]
# #### ALTERNATIVA MÁS POTENTE AL "FOR"

# %%
fruits = ["apple", "banana", "cherry", "kiwi", "mango"]
newlist = []

for x in fruits:
    if "a" in x:
        newlist.append(x)

print(newlist)
# Out:
# ['apple', 'banana', 'mango']

# %%
fruits = ["apple", "banana", "cherry", "kiwi", "mango"]

newlist = [x for x in fruits if "a" in x]

print(newlist)
# Out:
# ['apple', 'banana', 'mango']

# %% [markdown]
# #### SOLUCIONES A TYPOS

# %%
results_df.loc[:, 'rol_v_ctima_o_autoria'] = results_df.rol_v_ctima_o_autoria.replace('víctima', 'Víctima')

# %%
for i in llista_categories:
    boludo = results_df[i].value_counts()
    print(boludo)
    
#boludo, boludo.index
# Out:
# 2021    1027
# 2020     942
# Name: any, dtype: int64
# 6     248
# 2     235
# 7     198
# 8     192
# 5     189
# 10    175
# 9     167
# 11    140
# 3     127
# 12    111
# 4      97
# 1      90
# Name: n_m_mes, dtype: int64
# Juny        248
# Febrer      235
# Juliol      198
# Agost       192
# Maig        189
# Octubre     175
# Setembre    167
# Novembre    140
# Març        127
# Desembre    111
# Abril        97
# Gener        90
# Name: nom_mes, dtype: int64
# RP Metropolitana Barcelona    542
# RP  Metropolitana Nord        422
# RP Metropolitana Sud          250
# RP Girona                     219
# RP Central                    215
# RP Camp de Tarragona          169
# RP Ponent                     124
# RP Terres de l'Ebre            22
# RP Pirineu Occidental           6
# Name: regi_policial_rp, dtype: int64
# ABP Ciutat Vella                         125
# ABP Eixample                             103
# ABP Segrià - Garrigues - Pla d'Urgell     97
# ABP Sant Martí                            97
# ABP Badalona                              84
#                                         ...
# ABP el Prat de Llobregat                   2
# ABP Ripollès                               2
# ABP Noguera                                2
# Unitat d'informació RPMB                   1
# CD Caldes de Montbui                       1
# Name: rea_b_sica_policial_abp, Length: 62, dtype: int64
# Barcelona    1411
# Girona        223
# Tarragona     190
# Lleida        145
# Name: prov_ncia, dtype: int64
# Barcelonès           682
# Vallès Occidental    168
# Baix Llobregat       133
# Vallès Oriental       86
# Segrià                84
# Selva                 79
# Garraf                75
# Gironès               72
# Anoia                 67
# Maresme               65
# Baix Camp             62
# Bages                 56
# Osona                 53
# Baix Penedès          52
# Tarragonès            47
# Alt Empordà           24
# Baix Empordà          22
# Urgell                22
# Solsonès              18
# Baix Ebre             13
# Garrotxa              11
# Moianès               10
# Montsià                9
# Pla de l'Estany        9
# Pla d'Urgell           8
# Berguedà               6
# Alt Penedès            6
# Garrigues              5
# Vic                    4
# Cerdanya               3
# Segarra                3
# Alt Camp               3
# Conca de Barberà       3
# Val d'Aran             3
# Noguera                2
# Ripollès               2
# Priorat                1
# Bagès                  1
# Name: comarca, dtype: int64
# Barcelona                  541
# Lleida                      76
# Badalona                    74
# Girona                      49
# Sabadell                    47
#                           ...
# Vila-seca                    1
# Anglesola                    1
# Martorell                    1
# Olèrdola                     1
# Sant Feliu de Buixalleu      1
# Name: municipi, Length: 214, dtype: int64
# Via pública urbana                                 869
# Habitatge - Primera residència - Pis/apartament    283
# Habitatge - Primera residència - Casa adossada      61
# Habitatge - Escala/portal finca/replà               60
# Institut d'Educació                                 55
#                                                   ...
# Oficines/Despatxos professionals                     1
# Edifici/Infraestructura en desús                     1
# Dependències - Policia local                         1
# Establiments - Discoteca de joventut                 1
# Establiment - Benzinera - Centre comercial           1
# Name: tipus_de_lloc_dels_fets, Length: 96, dtype: int64
# Delicte                     958
# Delictes                    931
# Altres                       45
# Infracció administrativa     24
# Faltes Administratives       11
# Name: tipus_de_fet, dtype: int64
# Contra exercici drets fonamentals i llibertats públiques                            561
# Lesions                                                                             241
# Amenaces                                                                            223
# Amenaces (lleu)                                                                     164
# Lesions (lleu)                                                                      138
# Tracte degradant / vexatori                                                         109
# Danys                                                                               108
# Robatori amb violència i/o intimidació                                               69
# Diligències informatives                                                             45
# Injúria                                                                              32
# Furt                                                                                 29
# Assetjament                                                                          24
# Danys (lleu)                                                                         23
# Coaccions                                                                            20
# Coaccions (lleu)                                                                     15
# Furt (lleu)                                                                          15
# Danys / deslluïments de béns mobles / immobles                                       15
# Trencament de condemna                                                               12
# Violència física o psíquica habitual en l'àmbit familiar                             10
# Abusos sexuals                                                                        9
# Descobriment i revelació de secrets                                                   9
# Falta de maltractament d'obra sense lesió                                             9
# Injúria (lleu)                                                                        8
# Contra la llibertat de consciència, religió i respecte als difunts                    7
# Contra la llibertat de consciència i sentiments religiosos                            5
# Desordres públics                                                                     5
# Robatori amb força interior vehicle                                                   4
# Actes d'exhibició obscena/atemptat llibertat sexual                                   4
# Entrada a domicili aliè                                                               4
# Lesions (pèrdua membre/òrgan principal)                                               4
# Homicidi dolós (inclou temptativa i consumat)                                         4
# Maltractaments en l'àmbit de la llar                                                  3
# Robatori amb força                                                                    3
# Contra les institucions de l'Estat i divisió de poders                                3
# Assassinat                                                                            3
# Altres delictes contra l'ordre públic                                                 3
# Reunió, manifestació no comunicada                                                    2
# Assetjament/comportament agressiu vers col·lectiu                                     2
# Agressions sexuals                                                                    2
# Contra la comunitat internacional                                                     2
# Atemptat a autoritat, agents de l' autoritat i resistència i desobediència            2
# Trencament de condemna (resolució judicial)                                           2
# Emetre públicament expressions vexatòries                                             2
# Assetjament sexual                                                                    2
# Actes d'exhibició obscena/atempten contra la llibertat sexual                         2
# Incendi                                                                               2
# Abusos sexuals (víctima menor de 16 anys)                                             2
# Reunió, manifestació no comunicada/prohibida instal·lació bàsica                      2
# Infraccions ordenança convivència ciutadana                                           1
# Actes comportin aïllament, rebuig o menyspreu                                         1
# Diversos sense especificar                                                            1
# Falta de respecte i consideració a persones membres Forces i Cossos de Seguretat      1
# Estafes                                                                               1
# Name: tipus_de_fet_codi_penal_o, dtype: int64
# LGTBI-fòbia                            870
# Ètnic, origen nacional i/o racial      350
# Ètnia/origen nacional/origen racial    330
# Orientació política                    287
# Sexisme                                 43
# Religiós                                38
# Antisemita                              16
# Discapacitat física/sensorial           15
# Aporofòbia                               8
# Discapactiat psíquica/mental             6
# Discapacitat psíquica/mental             6
# Name: mbit_procediment_fet, dtype: int64
# Víctima             581
# Víctimes            557
# Persona autora      446
# Persones autores    385
# Name: rol_v_ctima_o_autoria, dtype: int64
# Home    1366
# Dona     603
# Name: sexe, dtype: int64
# 14    64
# 15    59
# 19    57
# 47    52
# 42    51
#       ..
# 9      1
# 5      1
# 78     1
# 2      1
# 90     1
# Name: edat_inici_fets, Length: 78, dtype: int64
# 1    1968
# Name: nombre, dtype: int64

# %%
llista_categories
dic_n_m_mes = {}
dic_nom_mes = {}
dic_regi_policial_rp = {}
dic_rea_b_sica_policial_abp = {}
dic_prov_ncia = {}
# Out:
# ['any',
#  'n_m_mes',
#  'nom_mes',
#  'regi_policial_rp',
#  'rea_b_sica_policial_abp',
#  'prov_ncia',
#  'comarca',
#  'municipi',
#  'tipus_de_lloc_dels_fets',
#  'tipus_de_fet',
#  'tipus_de_fet_codi_penal_o',
#  'mbit_procediment_fet',
#  'rol_v_ctima_o_autoria',
#  'sexe',
#  'edat_inici_fets',
#  'nombre']

# %%
boludo = results_df['any'].value_counts()
values_any = []
for i in boludo:
    values_any.append(i)    
#values_any

#boludo.index
respostes_any = []
for i in boludo.index:
    respostes_any.append(i)
    
any_dic = {}
k = 0
while k < len(values_any):
    any_dic[respostes_any[k]] = values_any[k]
    k += 1
any_dic
